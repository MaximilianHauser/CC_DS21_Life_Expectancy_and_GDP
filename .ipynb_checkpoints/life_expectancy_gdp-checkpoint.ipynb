# %% [markdown]
# # Codecademy Portfolio Project: Life expectancy and GDP
#
# Goal:
#  - try and identify the relationship between the GDP and life expectancy (LE) of six countries
#  - creating a blog post to share your findings
#
# Provided Resources:
#  - all_data.csv

# %%
# import section ------------------------------------------------------------------------------------------------------------- #
# updated with progress, sorted by purpose of the library -------------------------------------------------------------------- #

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# globally disable scientific notation, limit to two decimals ---------------------------------------------------------------- #
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# Loading the provided csv file and taking a look at it to get an overview over the provided data

# %%
all_data_df = pd.read_csv("./CC_provided_resources/all_data.csv")
all_data_df.head(10)
all_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# Initial insights:
#  - all_data is provided in long form, needs to be reshaped for analysis
#  - dtypes: gdp is provided as float needs to be converted to integer
#  - no null-values, need to check if other notation is used as null
#  - data provided by world bank, is it possible to aquire a more comprehensive data regarding gdp and le metrics of the six countries?
#
# Initial analysis questions:
#  - causal:
#    - can a relation between gdp and le be expected?
#      - gdp encompases an entire country, not an individual metric, does not account for wealth distribution
#      - le is an individual metric
#      - within a country, should be plausible, as the population should be somewhat stable
#      - look for additional metrics regarding gdp and le
#
#  - descriptive:
#    - performed on more comprehensive data
#
#  - correlational:
#    - performed on more comprehensive data

# %% [markdown]
# Given the comprehensive data provided by the world bank, the decision was made to download a more comprehensive set, as an increased amount of data points will provide a more reliable conclusion.
#
# The new data file for the six countries (CHL, CHN, DEU, MEX, USA, ZWE) contains the following metrics for the years from 1960 until 2021:
#
# - Life Epectancy from birth
# - GDP, PPP (based on purchasing power parity)
# - GDP per capita, PPP

# %% [markdown]
# Loading the downloaded csv file and taking a look at it to get an overview over the data

# %%
wdi_df = pd.read_excel("./Data_Extract_From_World_Development_Indicators/wdi_excel.xlsx")

# %% [markdown]
# Initial causal analysis questions:
#    - can a relation between gdp and le be expected?
#      - gdp encompases an entire country, not an individual metric, does not account for wealth distribution
#      - le is an individual metric
#      - within a country, should be plausible, as the population should be somewhat stable
#      - gdp per capita included, for added comparability between countries
#      - did not include further metrics, like inequality index, to not bloat the scope of the project to much (also the goal was to identify relationship between gdp and le for six countries, not to explain le as good as possible)

# %% [markdown]
# Beginning of the descriptive analysis
#  - will print entire df, as wide form takes up little space in jupyter

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None)
wdi_df
# Out:
#      Country Name Country Code  \
# 0           China          CHN
# 1           China          CHN
# 2           China          CHN
# 3           Chile          CHL
# 4           Chile          CHL
# 5           Chile          CHL
# 6         Germany          DEU
# 7         Germany          DEU
# 8         Germany          DEU
# 9          Mexico          MEX
# 10         Mexico          MEX
# 11         Mexico          MEX
# 12  United States          USA
# 13  United States          USA
# 14  United States          USA
# 15       Zimbabwe          ZWE
# 16       Zimbabwe          ZWE
# 17       Zimbabwe          ZWE
#
#                                           Series Name        Series Code  \
# 0            GDP, PPP (constant 2017 international $)  NY.GDP.MKTP.PP.KD
# 1   GDP per capita, PPP (constant 2017 internation...  NY.GDP.PCAP.PP.KD
# 2             Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# ...

# %% [markdown]
# Insights gained from "looking" at the dataframe:
#  - dataframe is in long form, needs to be reshaped for analysis
#  - .. used as null
#  - 1960 - 1989 and 2021 has missing values in gdp and gdp per capita
#  - Series Code or Series Name can be dropped because of redundancy
#  - Series Code or Series Name can be renamed into a more readable lable
#  - Country Code or Country Name can be dropped because of redundancy
#  - Year columns can be renamed into a more readable lable
#  - floats can be rounded or converted to integer for better readability, without loss of accuracy

# %%
wdi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   18 non-null     object
#  1   Country Code   18 non-null     object
#  2   Series Name    18 non-null     object
#  3   Series Code    18 non-null     object
#  4   1960 [YR1960]  18 non-null     object
#  5   1961 [YR1961]  18 non-null     object
#  6   1962 [YR1962]  18 non-null     object
#  7   1963 [YR1963]  18 non-null     object
#  8   1964 [YR1964]  18 non-null     object
#  9   1965 [YR1965]  18 non-null     object
#  10  1966 [YR1966]  18 non-null     object
#  11  1967 [YR1967]  18 non-null     object
#  12  1968 [YR1968]  18 non-null     object
#  13  1969 [YR1969]  18 non-null     object
#  14  1970 [YR1970]  18 non-null     object
#  15  1971 [YR1971]  18 non-null     object
#  16  1972 [YR1972]  18 non-null     object
# ...

# %% [markdown]
#  - Mixed data types in columns to be dropped, rest float(64), Codes and Names propably not cast as string

# %% [markdown]
# Dropping, renaming, reshaping and changing data types, to be able to get meaningfull summary statistics for desciptive analysis as well as ease of use

# %%
# Dropping columns, because of redundancy and missing values ----------------------------------------------------------------- #
# dropping redundant columns ------------------------------------------------------------------------------------------------- #

wdi_df.drop(columns = ['Country Name', 'Series Name'], inplace=True)

# replacing .. with null, as one possible approach of dropping missing value columns ----------------------------------------- #
wdi_df.replace('..', np.nan, inplace=True)
# drop columns (axis = 1) containing nan(null) values ------------------------------------------------------------------------ #
wdi_df.dropna(axis=1, inplace=True)

# Renaming Columns for ease of use ------------------------------------------------------------------------------------------- #
# Renaming "Country Code" and "Series Code" ---------------------------------------------------------------------------------- #
wdi_df.rename(columns={"Country Code":"Country", "Series Code":"Metric"}, inplace=True)

# Renaming the Years from 1990[YR1990] to 1990 ------------------------------------------------------------------------------- #
years_lst = list(wdi_df.columns)
rem_lst = ["Country", "Metric"]
for item in rem_lst:
    years_lst.remove(item)

rename_dict = {}

for i in range(len(years_lst)):
    year = 1990 + i
    rename = {str(year)+" [YR"+str(year)+"]":str(year)}
    rename_dict.update(rename)
    years_lst.append(str(year))

wdi_df.rename(columns=rename_dict, inplace=True)

# replace Series Codes with easier to use labels ----------------------------------------------------------------------------- #
rep_lst = ["NY.GDP.MKTP.PP.KD", "NY.GDP.PCAP.PP.KD", "SP.DYN.LE00.IN"]
val_lst = ["GDP", "GDPpc", "LE"]
wdi_df["Metric"].replace(to_replace = rep_lst, value = val_lst, inplace=True)

# reshaping wdi_df from to "longer" form ------------------------------------------------------------------------------------- #
wdi_df = (wdi_df.set_index(["Country","Metric"])
         .stack()
         .unstack(1)
         .rename_axis(columns=None, index=("Country","Year"))
         .reset_index())

# change data types of values in columns to be easier to work with ----------------------------------------------------------- #
wdi_df = wdi_df.astype({"Country":"string", "Year":"string"})

wdi_df = wdi_df.round({"GDP":2, "GDPpc":2, "LE":2})

# long wdi_df (l_wdi_df), as might be needed for some table operations, plots ------------------------------------------------ #
l_wdi_df = pd.melt(wdi_df, id_vars=["Country", "Year"], var_name="Metric", value_name="Value")

# checking if types are cast as intended ------------------------------------------------------------------------------------- #
wdi_df.dtypes
# Out:
# Country     string
# Year        string
# GDP        float64
# GDPpc      float64
# LE         float64
# dtype: object

# %% [markdown]
# Getting the Summary statistics for each metric per country

# %%
wdi_df[["Country", "GDP", "GDPpc", "LE"]].groupby("Country").describe()
# Out:
#           GDP                                                       \
#         count              mean              std               min
# Country
# CHL     31.00   304871126014.48  109494827820.89   129450154199.99
# CHN     31.00  9385638239326.81 6887661843562.72  1616385775698.94
# DEU     31.00  3698517588854.03  445957834125.72  2915150994424.49
# MEX     31.00  1885840436069.63  385799135146.39  1254868455671.90
# USA     31.00 15360620522480.24 3208677489169.16 10086517371119.24
# ZWE     31.00    28865752634.30    5060404709.67    17177213573.04
#
#                                                                \
#                       25%               50%               75%
# Country
# CHL       221224086890.15   297880564256.47   413708735340.08
# CHN      3595574559655.37  6954885516694.85 14589270721513.18
# DEU      3332567177865.42  3624472393448.37  4019808599303.54
# MEX      1588586073841.23  1885682929642.06  2195464899863.38
# ...

# %% [markdown]
# Boxplots for the summary statistics above (except count, standard deviation, mean) again grouped by metric and country

# %%
l_wdi_df
# Out:
#     Country  Year Metric             Value
# 0       CHL  1990    GDP   129450154199.99
# 1       CHL  1991    GDP   139552951918.62
# 2       CHL  1992    GDP   155136422193.40
# 3       CHL  1993    GDP   165358025688.02
# 4       CHL  1994    GDP   173675861751.80
# 5       CHL  1995    GDP   189190840335.69
# 6       CHL  1996    GDP   202061335410.69
# 7       CHL  1997    GDP   216997182486.56
# 8       CHL  1998    GDP   226069588670.12
# 9       CHL  1999    GDP   225450991293.75
# 10      CHL  2000    GDP   236659561222.49
# 11      CHL  2001    GDP   244123886435.85
# 12      CHL  2002    GDP   251942684159.44
# 13      CHL  2003    GDP   263842555068.61
# 14      CHL  2004    GDP   281452077797.84
# 15      CHL  2005    GDP   297880564256.47
# 16      CHL  2006    GDP   315902311065.35
# 17      CHL  2007    GDP   332228872189.06
# 18      CHL  2008    GDP   344818329172.42
# 19      CHL  2009    GDP   340963131854.24
# 20      CHL  2010    GDP   360915104444.85
# ...

# %%
# boxplot with x values as GDP, GDPpc, LE, grouped by country ---------------------------------------------------------------- #

g = sns.FacetGrid(l_wdi_df, col="Metric", sharey=False)

g.map(sns.boxplot, "Country", "Value", order=["CHL", "CHN", "DEU", "MEX", "USA", "ZWE"], palette="bright")
g.set(xlabel=None, ylabel=None)

ax = g.axes.flatten()
ax[0].set_title("GDP")
ax[1].set_title("GDPpc")
ax[2].set_title("LE")
# Out:
# Text(0.5, 1.0, 'LE')

# %% [markdown]
# Descriptive analysis:
#  - large variations between the countries regarding:
#    - central tendency (mean, median)
#    - variation (range, standard deviation, interquartile range)
#    - quartiles, min and max
#    - shape (skewedness of CHN vs USA)
#  - visually not necesserally a connection between GDP and LE suggested

# %% [markdown]
# Correlational analysis

# %%
# check for overall correlation between the variables ------------------------------------------------------------------------ #
chl_corr = wdi_df[wdi_df["Country"]=="CHL"].corr()
chn_corr = wdi_df[wdi_df["Country"]=="CHN"].corr()
deu_corr = wdi_df[wdi_df["Country"]=="DEU"].corr()
mex_corr = wdi_df[wdi_df["Country"]=="MEX"].corr()
usa_corr = wdi_df[wdi_df["Country"]=="USA"].corr()
zwe_corr = wdi_df[wdi_df["Country"]=="ZWE"].corr()
all_corr = wdi_df.corr()

# plot a heatmap for better visual readability ------------------------------------------------------------------------------- #
plt.clf()

fig = plt.figure(figsize=(10,4.5))
fig.subplots_adjust(hspace=0.2, wspace=0.1)

ax = fig.add_subplot(2, 6, 4)
sns.heatmap(chl_corr, vmin=-1, vmax=1, xticklabels=False, yticklabels=False, cmap="vlag", annot=True, cbar=False, ax=ax)
plt.title("CHL")

ax = fig.add_subplot(2, 6, 5)
sns.heatmap(chn_corr, vmin=-1, vmax=1, xticklabels=False, yticklabels=False, cmap="vlag", cbar=False, annot=True, ax=ax)
plt.title("CHN")

ax = fig.add_subplot(2, 6, 6)
sns.heatmap(deu_corr, vmin=-1, vmax=1, xticklabels=False, yticklabels=False, cmap="vlag", annot=True, cbar=False, ax=ax)
plt.title("DEU")

ax = fig.add_subplot(2, 6, 10)
sns.heatmap(mex_corr, vmin=-1, vmax=1, xticklabels=False, yticklabels=False, cmap="vlag", annot=True, cbar=False, ax=ax)
plt.title("MEX")

ax = fig.add_subplot(2, 6, 11)
sns.heatmap(usa_corr, vmin=-1, vmax=1, xticklabels=False, yticklabels=False, cmap="vlag", annot=True, cbar=False, ax=ax)
plt.title("USA")

ax = fig.add_subplot(2, 6, 12)
sns.heatmap(zwe_corr, vmin=-1, vmax=1, xticklabels=False, yticklabels=False, cmap="vlag", annot=True, cbar=False, ax=ax)
plt.title("ZWE")

ax = fig.add_subplot(1, 2, 1)
sns.heatmap(all_corr, vmin=-1, vmax=1, xticklabels=all_corr.columns, yticklabels=all_corr.columns, cmap="vlag", annot=True, ax=ax)
plt.yticks(rotation=30)
plt.title("ALL")

plt.show()

# %%
# Scatterplots for GDP and LE ------------------------------------------------------------------------------------------------ #
# subsets of wdi_df for scatterplots GDP vs LE ------------------------------------------------------------------------------- #
all_gdp_wdi_sdf = wdi_df[["GDP", "LE"]]
chl_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "CHL"]
chn_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "CHN"]
deu_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "DEU"]
mex_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "MEX"]
usa_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "USA"]
zwe_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "ZWE"]

# figure and plots ----------------------------------------------------------------------------------------------------------- #

plt.clf()

fig = plt.figure(figsize=(10,4.5))
fig.subplots_adjust(hspace=0.2, wspace=0.1)

ax = fig.add_subplot(2, 6, 4)
sns.scatterplot(data=chl_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.title("CHL")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 5)
sns.scatterplot(data=chn_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.title("CHN")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 6)
sns.scatterplot(data=deu_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.title("DEU")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 10)
sns.scatterplot(data=mex_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.title("MEX")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 11)
sns.scatterplot(data=usa_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.title("USA")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 12)
sns.scatterplot(data=zwe_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.title("ZWE")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(1, 2, 1)
sns.scatterplot(data=all_gdp_wdi_sdf, x="GDP", y="LE", ax=ax)
plt.yticks(rotation=30)
plt.ylabel("LE", rotation=0)
plt.title("ALL")

plt.show()

# %%
# Scatterplots for GDPpc and LE ------------------------------------------------------------------------------------------------ #
# subsets of wdi_df for scatterplots GDP vs LE ------------------------------------------------------------------------------- #
all_gdp_wdi_sdf = wdi_df[["GDPpc", "LE"]]
chl_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "CHL"]
chn_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "CHN"]
deu_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "DEU"]
mex_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "MEX"]
usa_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "USA"]
zwe_gdp_wdi_sdf = wdi_df.loc[wdi_df["Country"] == "ZWE"]

# figure and plots ----------------------------------------------------------------------------------------------------------- #

plt.clf()

fig = plt.figure(figsize=(10,4.5))
fig.subplots_adjust(hspace=0.2, wspace=0.1)

ax = fig.add_subplot(2, 6, 4)
sns.scatterplot(data=chl_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.title("CHL")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 5)
sns.scatterplot(data=chn_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.title("CHN")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 6)
sns.scatterplot(data=deu_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.title("DEU")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 10)
sns.scatterplot(data=mex_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.title("MEX")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 11)
sns.scatterplot(data=usa_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.title("USA")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(2, 6, 12)
sns.scatterplot(data=zwe_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.title("ZWE")
plt.xlabel("")
plt.ylabel("")
plt.xticks(ticks=[])
plt.yticks(ticks=[])

ax = fig.add_subplot(1, 2, 1)
sns.scatterplot(data=all_gdp_wdi_sdf, x="GDPpc", y="LE", ax=ax)
plt.yticks(rotation=30)
plt.ylabel("LE", rotation=0)
plt.title("ALL")

plt.show()

# %% [markdown]
# Correlational analysis:
#  - CHL, CHN, DEU, USA have almost perfect correlation between GDP, or GDPpc and LE
#  - MEX has extremely high correlation (more than 80% explained) between GDP, or GDPpc and LE
#  - CHL, CHN, DEU, USA, MEX have (almost) perfect correlation between GDP and GDPpc
#  - ZWE only has 045 of LE explained by GDP and only 0.15 by GDPpc
#  - high correlation suggests that LE is dependent on GDP
#  - Or did they just grow indepndent of each other? (correlation without causality, suggested by the lower correlation, when all points where included)
